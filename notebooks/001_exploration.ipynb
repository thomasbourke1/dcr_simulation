# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve

# %%
def calculate_N_tr(c, M_g):
    # average number of carriers trapped after a current pulse
    N_tr = c * M_g / (1-c)
    return N_tr


def calculate_tau_star(M_0, GB):
    # Effective transit time of carriers (not sure from where)
    return M_0 / (2 * np.pi * GB)

def calculate_P_d(P_d):
    # Calculates dark count probability per pulse. I_DM is primary dark current and the main thing we might vary


    P_a = 0.1 # Avalanche probability (could also find from McIntyre model)
    I_DM = 0.1e-12 # primary dark current
    tau = 2e-9 # Gate pulse width
    tau_d = 200e-9 # Trap time constant
    ELECTRONIC_CHARGE = 1.602e-19 # Electronic charge
    M_0 = 10 #DC gain
    GB = 30e9 # Gain bandwidth 
    c= 0.01 # Radio fo trapped carriers to the total carriers generated per avalanche pulse
    M_g = 1e8 # Gain when gate applied I think?
    delta_T = 1e-5 # Reciprocal of pulse repetiion rate 1GHz = 1ns

    P_d = 1 - np.exp(
        -P_a * ( (I_DM * tau / ELECTRONIC_CHARGE) + (I_DM * M_0**2 / (2* np.pi * GB))
                + (P_d * calculate_N_tr(c, M_g) * (np.exp(tau / tau_d)-1)/(np.exp(delta_T / tau_d)-1)) 
                + (P_d * calculate_N_tr(c, M_g) * (np.exp(calculate_tau_star(M_0, GB) / tau_d)-1/np.exp(delta_T / tau_d)-1) ) )
    )

    return P_d


def g(P_d):
    return calculate_P_d(P_d) - P_d

P_d_initialGuess = 1e-4

P_d_solution = fsolve(g, P_d_initialGuess)

print("P_d =", P_d_solution[0])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 40
#      36     return calculate_P_d(P_d) - P_d
#      38 P_d_initialGuess = 1e-4
# ---> 40 P_d_solution = fsolve(g, P_d_initialGuess)
#      42 print("P_d =", P_d_solution[0])
#
# File c:\Users\tbourke\GitHub\2026\dcr_simulation\venv\Lib\site-packages\scipy\optimize\_minpack_py.py:171, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     161 _wrapped_func.nfev = 0
#     163 options = {'col_deriv': col_deriv,
#     164            'xtol': xtol,
#     165            'maxfev': maxfev,
#    (...)    168            'factor': factor,
#     169            'diag': diag}
# --> 171 res = _root_hybr(_wrapped_func, x0, args, jac=fprime, **options)
#     172 res.nfev = _wrapped_func.nfev
#     174 if full_output:
#
# File c:\Users\tbourke\GitHub\2026\dcr_simulation\venv\Lib\site-packages\scipy\optimize\_minpack_py.py:239, in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     237 if not isinstance(args, tuple):
#     238     args = (args,)
# --> 239 shape, dtype = _check_func('fsolve', 'func', func, x0, args, n, (n,))
#     240 if epsfcn is None:
#     241     epsfcn = finfo(dtype).eps
#
# File c:\Users\tbourke\GitHub\2026\dcr_simulation\venv\Lib\site-packages\scipy\optimize\_minpack_py.py:24, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# File c:\Users\tbourke\GitHub\2026\dcr_simulation\venv\Lib\site-packages\scipy\optimize\_minpack_py.py:159, in fsolve.<locals>._wrapped_func(*fargs)
#     154 """
#     155 Wrapped `func` to track the number of times
#     156 the function has been called.
#     157 """
#     158 _wrapped_func.nfev += 1
# --> 159 return func(*fargs)
#
# Cell In[6], line 36, in g(P_d)
#      35 def g(P_d):
# ---> 36     return calculate_P_d(P_d) - P_d
#
# Cell In[6], line 28, in calculate_P_d(P_d)
#      23 M_g = 1e8 # Gain when gate applied I think?
#      24 delta_T = 1e-5 # Reciprocal of pulse repetiion rate 1GHz = 1ns
#      26 P_d = 1 - np.exp(
#      27     -P_a * ( (I_DM * tau / ELECTRONIC_CHARGE) + (I_DM * M_0**2 / (2* np.pi * GB))
# ---> 28             + (P_d * calculate_N_tr(c, M_g) * (np.exp(tau / tau_d)-1)/(np.exp(delta_T / tau_d)-1))
#      29             + (P_d * calculate_N_tr(c, M_g) * (np.exp(calculate_tau_star(M_0, GB) / tau_d)-1/np.exp(delta_T / tau_d)-1) ) )
#      30 )
#      32 return P_d
#
# Cell In[6], line 3, in calculate_N_tr(c, M_g)
#       1 def calculate_N_tr(c, M_g):
#       2     # average number of carriers trapped after a current pulse
# ----> 3     N_tr = c * M_g / (1-c)
#       4     return N_tr
#
# ZeroDivisionError: float division by zero
